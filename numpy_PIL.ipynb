# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f'NumPy version = {np.__version__}')
# Out:
# NumPy version = 1.19.5

# %%
# conda install pillow
from PIL import Image, ImageDraw, ImageFont # pillow package (Python Image Library)
import io

# %%
img = Image.open('tiger.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=203x141 at 0x7F3998CA42D0>

# %%
img.size # (width, height)
# Out:
# (203, 141)

# %%
a=np.uint8(img)
a.shape
# Out:
# (141, 203, 4)

# %%
Image.fromarray(a)
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3998C47350>

# %%
Image.fromarray(a[::-1])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C36CD0>

# %%
Image.fromarray(a[:, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C3EB10>

# %%
Image.fromarray(a[::-1, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994BE64D0>

# %%
Image.fromarray(a[:, ::-1, :])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994BCBA10>

# %%
Image.fromarray(a[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C29DD0>

# %%
a.shape
# Out:
# (141, 203, 4)

# %%
a.strides
# Out:
# (812, 4, 1)

# %%
b=a.transpose(1, 0, 2).strides
b[:5]
# Out:
# (4, 812, 1)

# %%
Image.fromarray(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c52daefb8e3e> in <module>()
# ----> 1 Image.fromarray(b)
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2668     .. versionadded:: 1.1.6
#    2669     """
# -> 2670     arr = obj.__array_interface__
#    2671     shape = arr["shape"]
#    2672     ndim = len(shape)
#
# AttributeError: 'tuple' object has no attribute '__array_interface__'

# %%
# a[100] = 0

# %%
a.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : False
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
a.setflags(write=1)

# %%
a[100:111] = [255, 0, 0, 255]

# %%
Image.fromarray(a)
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C6A150>

# %%
Image.fromarray(a[::-1])
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3998C1C590>

# %%
img2 = Image.fromarray(a)
img2
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994BB3CD0>

# %%
a.shape
# Out:
# (141, 203, 4)

# %%
Image.fromarray(np.uint8(a[::-1]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994B9AC90>

# %%
Image.fromarray(np.uint8(a[::-1]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C36710>

# %%
Image.fromarray(np.uint8(a[::-1]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C29D90>

# %%
Image.fromarray(np.uint8(a * .5))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994C36E50>

# %%
a = a * .5

# %%
Image.fromarray(np.uint8(a))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x141 at 0x7F3994B67490>

# %%
a.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
a.setflags(write=1)

# %%
a[::2] = 128

# %%
Image.fromarray(np.uint8(a[::2]))
# Out:
# <PIL.Image.Image image mode=RGBA size=203x71 at 0x7F3994B67ED0>

# %%
a
# Out:
# array([[[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ]],
#
#        [[127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         ...,
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5],
#         [127.5, 127.5, 127.5, 127.5]],
#
#        [[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ]],
#
#        ...,
#
#        [[128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         [128. , 128. , 128. , 128. ],
#         ...,
#         [128. , 128. , 128. , 128. ],
# ...

# %%
a[::2]
# Out:
# array([[[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        ...,
#
#        [[128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         ...,
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.],
#         [128., 128., 128., 128.]],
#
#        [[128., 128., 128., 128.],
# ...

# %%
a[:, :, 0]
# Out:
# array([[128. , 128. , 128. , ..., 128. , 128. , 128. ],
#        [127.5, 127.5, 127.5, ..., 127.5, 127.5, 127.5],
#        [128. , 128. , 128. , ..., 128. , 128. , 128. ],
#        ...,
#        [128. , 128. , 128. , ..., 128. , 128. , 128. ],
#        [127.5, 127.5, 127.5, ..., 127.5, 127.5, 127.5],
#        [128. , 128. , 128. , ..., 128. , 128. , 128. ]])

# %%
a[a[:, :, 0] > 0]
# Out:
# array([[128., 128., 128., 128.],
#        [128., 128., 128., 128.],
#        [128., 128., 128., 128.],
#        ...,
#        [128., 128., 128., 128.],
#        [128., 128., 128., 128.],
#        [128., 128., 128., 128.]])
